# %%
import geopandas as gpd

isos_2015 = gpd.read_file('DGUID_ISO_30min_2015.shp')
test = gpd.read_file('Toronto_Census_Tracts_No_Centroid_Final.shp')
test['area_percentage'] = isos_2015['area_perce']*100

# %%
import plotter
# print(test.columns)
# plotter.plot_choropleth(test, title = 'Homeownership rate (%)', column = 'Value')

# %%
(fig, ax) = plotter.plot_choropleth(test, title = 'Homeownership rate (%)', column = 'Value')

#plotter.plot_subway_lines(fig=fig, ax=ax, year = '2025')
plotter.plot_bus_lines(fig = fig, ax=ax, year = '2015')
plotter.plot_streetcar_lines(fig = fig, ax = ax, year = '2015')
plotter.plot_subway_lines(fig = fig, ax=ax, year = 2015)

(fig, ax) = plotter.plot_choropleth(test, title = 'Homeownership rate (%)', column = 'Value')

#plotter.plot_subway_lines(fig=fig, ax=ax, year = '2025')
plotter.plot_bus_lines(fig = fig, ax=ax, year = '2025')
plotter.plot_streetcar_lines(fig = fig, ax = ax, year = '2025')
plotter.plot_subway_lines(fig = fig, ax=ax, year = '2025')
